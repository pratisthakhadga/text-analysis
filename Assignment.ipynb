# %%
# Ask the user to enter the names of files to compare
fname1 = input("Enter the first filename: ")
fname2 = input("Enter the second filename: ")
# Out:
# Enter the first filename:  Hamlet.txt
# Enter the second filename:  Macbeth.txt

# %%
# Open file for reading in text mode (default mode)
f1 = open(fname1)
f2 = open(fname2)

# Print confirmation
print("-----------------------------------")
print("Comparing files ", " > " + fname1, " < " +fname2, sep='\n')
print("-----------------------------------")

# Read the first line from the files
f1_line = f1.readline()
f2_line = f2.readline()

# Initialize counter for line number
line_no = 1

# Loop if either file1 or file2 has not reached EOF
while f1_line != '' or f2_line != '':

    # Strip the leading whitespaces
    f1_line = f1_line.rstrip()
    f2_line = f2_line.rstrip()
    
    # Compare the lines from both file
    if f1_line != f2_line:
        
        # If a line does not exist on file2 then mark the output with + sign
        if f2_line == '' and f1_line != '':
            print(">+", "Line-%d" % line_no, f1_line)
        # otherwise output the line on file1 and mark it with > sign
        elif f1_line != '':
            print(">", "Line-%d" % line_no, f1_line)
            
        # If a line does not exist on file1 then mark the output with + sign
        if f1_line == '' and f2_line != '':
            print("<+", "Line-%d" % line_no, f2_line)
        # otherwise output the line on file2 and mark it with < sign
        elif f2_line != '':
            print("<", "Line-%d" %  line_no, f2_line)

        # Print a blank line
        print()

    #Read the next line from the file
    f1_line = f1.readline()
    f2_line = f2.readline()
# Out:
# -----------------------------------
# Comparing files
#  > Hamlet.txt
#  < Macbeth.txt
# -----------------------------------
# > Line-1 *********************The Tragedie of Hamlet*********************
# < Line-1 ********************The Tragedie of Macbeth*********************
#
# > Line-1 The Tragedie of Hamlet
# < Line-1 The Tragedie of Macbeth
#
# > Line-1 July, 2000  [Etext #2265]
# < Line-1 July, 2000  [Etext #2264]
#
# > Line-1 *********************The Tragedie of Hamlet*********************
# < Line-1 ********************The Tragedie of Macbeth*********************
#
# > Line-1 *****This file should be named 2265.txt or 2265.zip******
# < Line-1 *****This file should be named 2264.txt or 2264.zip******
#
# > Line-1 Project Gutenberg's Etext of Shakespeare's The Tragedie of Hamlet
# < Line-1 Project Gutenberg's Etext of Shakespeare's The Tragedie of Macbeth
#
# >+ Line-1 Executive Director's Notes:
#
# <+ Line-1 Executive Director's Notes:
#
# >+ Line-1 In addition to the notes below, and so you will *NOT* think all
#
# > Line-1 the spelling errors introduced by the printers of the time have
# < Line-1 In addition to the notes below, and so you will *NOT* think all
#
# > Line-1 been corrected, here are the first few lines of Hamlet, as they
# < Line-1 the spelling errors introduced by the printers of the time have
#
# > Line-1 are presented herein:
# < Line-1 been corrected, here are the first few lines of Hamlet, as they
#
# <+ Line-1 are presented herein:
#
# >+ Line-1   Barnardo. Who's there?
#
# > Line-1   Fran. Nay answer me: Stand & vnfold
# < Line-1   Barnardo. Who's there?
#
# > Line-1 your selfe
# < Line-1   Fran. Nay answer me: Stand & vnfold
#
# <+ Line-1 your selfe
#
# >+ Line-1    Bar. Long liue the King
#
# <+ Line-1    Bar. Long liue the King
#
# >+ Line-1 ***
#
# <+ Line-1 ***
#
# >+ Line-1 As I understand it, the printers often ran out of certain words
#
# > Line-1 or letters they had often packed into a "cliche". . .this is the
# < Line-1 As I understand it, the printers often ran out of certain words
#
# > Line-1 original meaning of the term cliche. . .and thus, being unwilling
# < Line-1 or letters they had often packed into a "cliche". . .this is the
#
# > Line-1 to unpack the cliches, and thus you will see some substitutions
# < Line-1 original meaning of the term cliche. . .and thus, being unwilling
#
# > Line-1 that look very odd. . .such as the exchanges of u for v, v for u,
# < Line-1 to unpack the cliches, and thus you will see some substitutions
#
# > Line-1 above. . .and you may wonder why they did it this way, presuming
# < Line-1 that look very odd. . .such as the exchanges of u for v, v for u,
#
# > Line-1 Shakespeare did not actually write the play in this manner. . . .
# < Line-1 above. . .and you may wonder why they did it this way, presuming
#
# <+ Line-1 Shakespeare did not actually write the play in this manner. . . .
#
# >+ Line-1 The answer is that they MAY have packed "liue" into a cliche at a
#
# > Line-1 time when they were out of "v"'s. . .possibly having used "vv" in
# < Line-1 The answer is that they MAY have packed "liue" into a cliche at a
#
# > Line-1 place of some "w"'s, etc.  This was a common practice of the day,
# < Line-1 time when they were out of "v"'s. . .possibly having used "vv" in
#
# > Line-1 as print was still quite expensive, and they didn't want to spend
# < Line-1 place of some "w"'s, etc.  This was a common practice of the day,
#
# > Line-1 more on a wider selection of characters than they had to.
# < Line-1 as print was still quite expensive, and they didn't want to spend
#
# <+ Line-1 more on a wider selection of characters than they had to.
#
# >+ Line-1 You will find a lot of these kinds of "errors" in this text, as I
#
# > Line-1 have mentioned in other times and places, many "scholars" have an
# < Line-1 You will find a lot of these kinds of "errors" in this text, as I
#
# > Line-1 extreme attachment to these errors, and many have accorded them a
# < Line-1 have mentioned in other times and places, many "scholars" have an
#
# > Line-1 very high place in the "canon" of Shakespeare.  My father read an
# < Line-1 extreme attachment to these errors, and many have accorded them a
#
# > Line-1 assortment of these made available to him by Cambridge University
# < Line-1 very high place in the "canon" of Shakespeare.  My father read an
#
# > Line-1 in England for several months in a glass room constructed for the
# < Line-1 assortment of these made available to him by Cambridge University
#
# > Line-1 purpose.  To the best of my knowledge he read ALL those available
# < Line-1 in England for several months in a glass room constructed for the
#
# > Line-1 . . .in great detail. . .and determined from the various changes,
# < Line-1 purpose.  To the best of my knowledge he read ALL those available
#
# > Line-1 that Shakespeare most likely did not write in nearly as many of a
# < Line-1 . . .in great detail. . .and determined from the various changes,
#
# > Line-1 variety of errors we credit him for, even though he was in/famous
# < Line-1 that Shakespeare most likely did not write in nearly as many of a
#
# > Line-1 for signing his name with several different spellings.
# < Line-1 variety of errors we credit him for, even though he was in/famous
#
# <+ Line-1 for signing his name with several different spellings.
#
# >+ Line-1 So, please take this into account when reading the comments below
#
# > Line-1 made by our volunteer who prepared this file:  you may see errors
# < Line-1 So, please take this into account when reading the comments below
#
# > Line-1 that are "not" errors. . . .
# < Line-1 made by our volunteer who prepared this file:  you may see errors
#
# <+ Line-1 that are "not" errors. . . .
#
# >+ Line-1 So. . .with this caveat. . .we have NOT changed the canon errors,
#
# > Line-1 here is the Project Gutenberg Etext of Shakespeare's The Tragedie
# < Line-1 So. . .with this caveat. . .we have NOT changed the canon errors,
#
# > Line-1 of Hamlet.
# < Line-1 here is the Project Gutenberg Etext of Shakespeare's The Tragedie
#
# <+ Line-1 of Macbeth.
#
# >+ Line-1 Michael S. Hart
#
# > Line-1 Project Gutenberg
# < Line-1 Michael S. Hart
#
# > Line-1 Executive Director
# < Line-1 Project Gutenberg
#
# <+ Line-1 Executive Director
#
# >+ Line-1 ***
#
# <+ Line-1 ***
#
# >+ Line-1 Scanner's Notes: What this is and isn't.  This was taken from
#
# > Line-1 a copy of Shakespeare's first folio and it is as close as I can
# < Line-1 Scanner's Notes: What this is and isn't.  This was taken from
#
# > Line-1 come in ASCII to the printed text.
# < Line-1 a copy of Shakespeare's first folio and it is as close as I can
#
# <+ Line-1 come in ASCII to the printed text.
#
# >+ Line-1 The elongated S's have been changed to small s's and the
#
# > Line-1 conjoined ae have been changed to ae.  I have left the spelling,
# < Line-1 The elongated S's have been changed to small s's and the
#
# > Line-1 punctuation, capitalization as close as possible to the
# < Line-1 conjoined ae have been changed to ae.  I have left the spelling,
#
# > Line-1 printed text.  I have corrected some spelling mistakes (I have put
# < Line-1 punctuation, capitalization as close as possible to the
#
# > Line-1 together a spelling dictionary devised from the spellings of the
# < Line-1 printed text.  I have corrected some spelling mistakes (I have put
#
# > Line-1 Geneva Bible and Shakespeare's First Folio and have unified
# < Line-1 together a spelling dictionary devised from the spellings of the
#
# > Line-1 spellings according to this template), typo's and expanded
# < Line-1 Geneva Bible and Shakespeare's First Folio and have unified
#
# > Line-1 abbreviations as I have come across them.  Everything within
# < Line-1 spellings according to this template), typo's and expanded
#
# > Line-1 brackets [] is what I have added.  So if you don't like that
# < Line-1 abbreviations as I have come across them.  Everything within
#
# > Line-1 you can delete everything within the brackets if you want a
# < Line-1 brackets [] is what I have added.  So if you don't like that
#
# > Line-1 purer Shakespeare.
# < Line-1 you can delete everything within the brackets if you want a
#
# <+ Line-1 purer Shakespeare.
#
# >+ Line-1 Another thing that you should be aware of is that there are textual
#
# > Line-1 differences between various copies of the first folio.  So there may
# < Line-1 Another thing that you should be aware of is that there are textual
#
# > Line-1 be differences (other than what I have mentioned above) between
# < Line-1 differences between various copies of the first folio.  So there may
#
# > Line-1 this and other first folio editions.  This is due to the printer's
# < Line-1 be differences (other than what I have mentioned above) between
#
# > Line-1 habit of setting the type and running off a number of copies and
# < Line-1 this and other first folio editions.  This is due to the printer's
#
# > Line-1 then proofing the printed copy and correcting the type and then
# < Line-1 habit of setting the type and running off a number of copies and
#
# > Line-1 continuing the printing run.  The proof run wasn't thrown away but
# < Line-1 then proofing the printed copy and correcting the type and then
#
# > Line-1 incorporated into the printed copies.  This is just the way it is.
# < Line-1 continuing the printing run.  The proof run wasn't thrown away but
#
# > Line-1 The text I have used was a composite of more than 30 different
# < Line-1 incorporated into the printed copies.  This is just the way it is.
#
# > Line-1 First Folio editions' best pages.
# < Line-1 The text I have used was a composite of more than 30 different
#
# <+ Line-1 First Folio editions' best pages.
#
# >+ Line-1 If you find any scanning errors, out and out typos, punctuation
#
# > Line-1 errors, or if you disagree with my spelling choices please feel
# < Line-1 If you find any scanning errors, out and out typos, punctuation
#
# > Line-1 free to email me those errors.  I wish to make this the best
# < Line-1 errors, or if you disagree with my spelling choices please feel
#
# > Line-1 etext possible.  My email address for right now are haradda@aol.com
# < Line-1 free to email me those errors.  I wish to make this the best
#
# > Line-1 and davidr@inconnect.com.  I hope that you enjoy this.
# < Line-1 etext possible.  My email address for right now are haradda@aol.com
#
# <+ Line-1 and davidr@inconnect.com.  I hope that you enjoy this.
#
# >+ Line-1 David Reed
#
# <+ Line-1 David Reed
#
# >+ Line-1 The Tragedie of Hamlet
#
# <+ Line-1 The Tragedie of Macbeth
#
# >+ Line-1 Actus Primus. Scoena Prima.
#
# <+ Line-1 Actus Primus. Scoena Prima.
#
# >+ Line-1 Enter Barnardo and Francisco two Centinels.
#
# <+ Line-1 Thunder and Lightning. Enter three Witches.
#
# >+ Line-1   Barnardo. Who's there?
#
# > Line-1   Fran. Nay answer me: Stand & vnfold
# < Line-1   1. When shall we three meet againe?
#
# > Line-1 your selfe
# < Line-1 In Thunder, Lightning, or in Raine?
#
# <+ Line-1   2. When the Hurley-burley's done,
#
# > Line-1    Bar. Long liue the King
# < Line-1 When the Battaile's lost, and wonne
#
# > Line-1    Fran. Barnardo?
# < Line-1    3. That will be ere the set of Sunne
#
# >+ Line-1   Bar. He
#
# <+ Line-1    1. Where the place?
#
# > Line-1    Fran. You come most carefully vpon your houre
# < Line-1   2. Vpon the Heath
#
# > Line-1    Bar. 'Tis now strook twelue, get thee to bed Francisco
# < Line-1    3. There to meet with Macbeth
#
# > Line-1    Fran. For this releefe much thankes: 'Tis bitter cold,
# < Line-1    1. I come, Gray-Malkin
#
# >+ Line-1 And I am sicke at heart
#
# <+ Line-1    All. Padock calls anon: faire is foule, and foule is faire,
#
# > Line-1    Barn. Haue you had quiet Guard?
# < Line-1 Houer through the fogge and filthie ayre.
#
# >+ Line-1   Fran. Not a Mouse stirring
#
# <+ Line-1 Exeunt.
#
# >+ Line-1    Barn. Well, goodnight. If you do meet Horatio and
#
# >+ Line-1 Marcellus, the Riuals of my Watch, bid them make hast.
#
# > Line-1 Enter Horatio and Marcellus.
# < Line-1 Scena Secunda.
#
# > Line-1   Fran. I thinke I heare them. Stand: who's there?
# < Line-1 Alarum within. Enter King, Malcome, Donalbaine, Lenox, with
#
# > Line-1   Hor. Friends to this ground
# < Line-1 attendants, meeting a bleeding Captaine.
#
# > Line-1    Mar. And Leige-men to the Dane
# < Line-1   King. What bloody man is that? he can report,
#
# <+ Line-1 As seemeth by his plight, of the Reuolt
#
# > Line-1    Fran. Giue you good night
# < Line-1 The newest state
#
# > Line-1    Mar. O farwel honest Soldier, who hath relieu'd you?
# < Line-1    Mal. This is the Serieant,
#
# > Line-1   Fra. Barnardo ha's my place: giue you goodnight.
# < Line-1 Who like a good and hardie Souldier fought
#
# <+ Line-1 'Gainst my Captiuitie: Haile braue friend;
#
# > Line-1 Exit Fran.
# < Line-1 Say to the King, the knowledge of the Broyle,
#
# <+ Line-1 As thou didst leaue it
#
# >+ Line-1   Mar. Holla Barnardo
#
# <+ Line-1    Cap. Doubtfull it stood,
#
# > Line-1    Bar. Say, what is Horatio there?
# < Line-1 As two spent Swimmers, that doe cling together,
#
# > Line-1   Hor. A peece of him
# < Line-1 And choake their Art: The mercilesse Macdonwald
#
# <+ Line-1 (Worthie to be a Rebell, for to that
#
# > Line-1    Bar. Welcome Horatio, welcome good Marcellus
# < Line-1 The multiplying Villanies of Nature
#
# <+ Line-1 Doe swarme vpon him) from the Westerne Isles
#
# > Line-1    Mar. What, ha's this thing appear'd againe to night
# < Line-1 Of Kernes and Gallowgrosses is supply'd,
#
# <+ Line-1 And Fortune on his damned Quarry smiling,
#
# > Line-1    Bar. I haue seene nothing
# < Line-1 Shew'd like a Rebells Whore: but all's too weake:
#
# <+ Line-1 For braue Macbeth (well hee deserues that Name)
#
# > Line-1    Mar. Horatio saies, 'tis but our Fantasie,
# < Line-1 Disdayning Fortune, with his brandisht Steele,
#
# > Line-1 And will not let beleefe take hold of him
# < Line-1 Which smoak'd with bloody execution
#
# > Line-1 Touching this dreaded sight, twice seene of vs,
# < Line-1 (Like Valours Minion) caru'd out his passage,
#
# > Line-1 Therefore I haue intreated him along
# < Line-1 Till hee fac'd the Slaue:
#
# > Line-1 With vs, to watch the minutes of this Night,
# < Line-1 Which neu'r shooke hands, nor bad farwell to him,
#
# > Line-1 That if againe this Apparition come,
# < Line-1 Till he vnseam'd him from the Naue toth' Chops,
#
# > Line-1 He may approue our eyes, and speake to it
# < Line-1 And fix'd his Head vpon our Battlements
#
# > Line-1    Hor. Tush, tush, 'twill not appeare
# < Line-1    King. O valiant Cousin, worthy Gentleman
#
# > Line-1    Bar. Sit downe a-while,
# < Line-1    Cap. As whence the Sunne 'gins his reflection,
#
# > Line-1 And let vs once againe assaile your eares,
# < Line-1 Shipwracking Stormes, and direfull Thunders:
#
# > Line-1 That are so fortified against our Story,
# < Line-1 So from that Spring, whence comfort seem'd to come,
#
# > Line-1 What we two Nights haue seene
# < Line-1 Discomfort swells: Marke King of Scotland, marke,
#
# <+ Line-1 No sooner Iustice had, with Valour arm'd,
#
# > Line-1    Hor. Well, sit we downe,
# < Line-1 Compell'd these skipping Kernes to trust their heeles,
#
# > Line-1 And let vs heare Barnardo speake of this
# < Line-1 But the Norweyan Lord, surueying vantage,
#
# <+ Line-1 With furbusht Armes, and new supplyes of men,
#
# > Line-1    Barn. Last night of all,
# < Line-1 Began a fresh assault
#
# >+ Line-1 When yond same Starre that's Westward from the Pole
#
# > Line-1 Had made his course t' illume that part of Heauen
# < Line-1    King. Dismay'd not this our Captaines, Macbeth and
#
# > Line-1 Where now it burnes, Marcellus and my selfe,
# < Line-1 Banquoh?
#
# > Line-1 The Bell then beating one
# < Line-1   Cap. Yes, as Sparrowes, Eagles;
#
# <+ Line-1 Or the Hare, the Lyon:
#
# > Line-1    Mar. Peace, breake thee of:
# < Line-1 If I say sooth, I must report they were
#
# > Line-1 Enter the Ghost.
# < Line-1 As Cannons ouer-charg'd with double Cracks,
#
# <+ Line-1 So they doubly redoubled stroakes vpon the Foe:
#
# > Line-1 Looke where it comes againe
# < Line-1 Except they meant to bathe in reeking Wounds,
#
# <+ Line-1 Or memorize another Golgotha,
#
# > Line-1    Barn. In the same figure, like the King that's dead
# < Line-1 I cannot tell: but I am faint,
#
# <+ Line-1 My Gashes cry for helpe
#
# >+ Line-1    Mar. Thou art a Scholler; speake to it Horatio
#
# <+ Line-1    King. So well thy words become thee, as thy wounds,
#
# > Line-1    Barn. Lookes it not like the King? Marke it Horatio
# < Line-1 They smack of Honor both: Goe get him Surgeons.
#
# <+ Line-1 Enter Rosse and Angus.
#
# >+ Line-1    Hora. Most like: It harrowes me with fear & wonder
#
# > Line-1   Barn. It would be spoke too
# < Line-1 Who comes here?
#
# <+ Line-1   Mal. The worthy Thane of Rosse
#
# >+ Line-1    Mar. Question it Horatio
#
# <+ Line-1    Lenox. What a haste lookes through his eyes?
#
# > Line-1    Hor. What art thou that vsurp'st this time of night,
# < Line-1 So should he looke, that seemes to speake things strange
#
# >+ Line-1 Together with that Faire and Warlike forme
#
# > Line-1 In which the Maiesty of buried Denmarke
# < Line-1    Rosse. God saue the King
#
# >+ Line-1 Did sometimes march: By Heauen I charge thee speake
#
# <+ Line-1    King. Whence cam'st thou, worthy Thane?
#
# > Line-1    Mar. It is offended
# < Line-1   Rosse. From Fiffe, great King,
#
# <+ Line-1 Where the Norweyan Banners flowt the Skie,
#
# > Line-1    Barn. See, it stalkes away
# < Line-1 And fanne our people cold.
#
# <+ Line-1 Norway himselfe, with terrible numbers,
#
# > Line-1    Hor. Stay: speake; speake: I Charge thee, speake.
# < Line-1 Assisted by that most disloyall Traytor,
#
# <+ Line-1 The Thane of Cawdor, began a dismall Conflict,
#
# > Line-1 Exit the Ghost.
# < Line-1 Till that Bellona's Bridegroome, lapt in proofe,
#
# <+ Line-1 Confronted him with selfe-comparisons,
#
# > Line-1   Mar. 'Tis gone, and will not answer
# < Line-1 Point against Point, rebellious Arme 'gainst Arme,
#
# <+ Line-1 Curbing his lauish spirit: and to conclude,
#
# > Line-1    Barn. How now Horatio? You tremble & look pale:
# < Line-1 The Victorie fell on vs
#
# >+ Line-1 Is not this something more then Fantasie?
#
# > Line-1 What thinke you on't?
# < Line-1    King. Great happinesse
#
# >+ Line-1   Hor. Before my God, I might not this beleeue
#
# > Line-1 Without the sensible and true auouch
# < Line-1    Rosse. That now Sweno, the Norwayes King,
#
# > Line-1 Of mine owne eyes
# < Line-1 Craues composition:
#
# <+ Line-1 Nor would we deigne him buriall of his men,
#
# > Line-1    Mar. Is it not like the King?
# < Line-1 Till he disbursed, at Saint Colmes ynch,
#
# > Line-1   Hor. As thou art to thy selfe,
# < Line-1 Ten thousand Dollars, to our generall vse
#
# >+ Line-1 Such was the very Armour he had on,
#
# > Line-1 When th' Ambitious Norwey combatted:
# < Line-1    King. No more that Thane of Cawdor shall deceiue
#
# > Line-1 So frown'd he once, when in an angry parle
# < Line-1 Our Bosome interest: Goe pronounce his present death,
#
# > Line-1 He smot the sledded Pollax on the Ice.
# < Line-1 And with his former Title greet Macbeth
#
# >+ Line-1 'Tis strange
#
# <+ Line-1    Rosse. Ile see it done
#
# >+ Line-1    Mar. Thus twice before, and iust at this dead houre,
#
# > Line-1 With Martiall stalke, hath he gone by our Watch
# < Line-1    King. What he hath lost, Noble Macbeth hath wonne.
#
# > Line-1    Hor. In what particular thought to work, I know not:
# < Line-1 Exeunt.
#
# >+ Line-1 But in the grosse and scope of my Opinion,
#
# >+ Line-1 This boades some strange erruption to our State
#
# <+ Line-1 Scena Tertia.
#
# >+ Line-1    Mar. Good now sit downe, & tell me he that knowes
#
# > Line-1 Why this same strict and most obseruant Watch,
# < Line-1 Thunder. Enter the three Witches.
#
# >+ Line-1 So nightly toyles the subiect of the Land,
#
# > Line-1 And why such dayly Cast of Brazon Cannon
# < Line-1   1. Where hast thou beene, Sister?
#
# > Line-1 And Forraigne Mart for Implements of warre:
# < Line-1   2. Killing Swine
#
# >+ Line-1 Why such impresse of Ship-wrights, whose sore Taske
#
# > Line-1 Do's not diuide the Sunday from the weeke,
# < Line-1    3. Sister, where thou?
#
# > Line-1 What might be toward, that this sweaty hast
# < Line-1   1. A Saylors Wife had Chestnuts in her Lappe,
#
# > Line-1 Doth make the Night ioynt-Labourer with the day:
# < Line-1 And mouncht, & mouncht, and mouncht:
#
# > Line-1 Who is't that can informe me?
# < Line-1 Giue me, quoth I.
#
# > Line-1   Hor. That can I,
# < Line-1 Aroynt thee, Witch, the rumpe-fed Ronyon cryes.
#
# > Line-1 At least the whisper goes so: Our last King,
# < Line-1 Her Husband's to Aleppo gone, Master o'th' Tiger:
#
# > Line-1 Whose Image euen but now appear'd to vs,
# < Line-1 But in a Syue Ile thither sayle,
#
# > Line-1 Was (as you know) by Fortinbras of Norway,
# < Line-1 And like a Rat without a tayle,
#
# > Line-1 (Thereto prick'd on by a most emulate Pride)
# < Line-1 Ile doe, Ile doe, and Ile doe
#
# >+ Line-1 Dar'd to the Combate. In which, our Valiant Hamlet,
#
# > Line-1 (For so this side of our knowne world esteem'd him)
# < Line-1    2. Ile giue thee a Winde
#
# >+ Line-1 Did slay this Fortinbras: who by a Seal'd Compact,
#
# > Line-1 Well ratified by Law, and Heraldrie,
# < Line-1    1. Th'art kinde
#
# >+ Line-1 Did forfeite (with his life) all those his Lands
#
# > Line-1 Which he stood seiz'd on, to the Conqueror:
# < Line-1    3. And I another
#
# >+ Line-1 Against the which, a Moity competent
#
# > Line-1 Was gaged by our King: which had return'd
# < Line-1    1. I my selfe haue all the other,
#
# > Line-1 To the Inheritance of Fortinbras,
# < Line-1 And the very Ports they blow,
#
# > Line-1 Had he bin Vanquisher, as by the same Cou'nant
# < Line-1 All the Quarters that they know,
#
# > Line-1 And carriage of the Article designe,
# < Line-1 I'th' Ship-mans Card.
#
# > Line-1 His fell to Hamlet. Now sir, young Fortinbras,
# < Line-1 Ile dreyne him drie as Hay:
#
# > Line-1 Of vnimproued Mettle, hot and full,
# < Line-1 Sleepe shall neyther Night nor Day
#
# > Line-1 Hath in the skirts of Norway, heere and there,
# < Line-1 Hang vpon his Pent-house Lid:
#
# > Line-1 Shark'd vp a List of Landlesse Resolutes,
# < Line-1 He shall liue a man forbid:
#
# > Line-1 For Foode and Diet, to some Enterprize
# < Line-1 Wearie Seu'nights, nine times nine,
#
# > Line-1 That hath a stomacke in't: which is no other
# < Line-1 Shall he dwindle, peake, and pine:
#
# > Line-1 (And it doth well appeare vnto our State)
# < Line-1 Though his Barke cannot be lost,
#
# > Line-1 But to recouer of vs by strong hand
# < Line-1 Yet it shall be Tempest-tost.
#
# > Line-1 And termes Compulsatiue, those foresaid Lands
# < Line-1 Looke what I haue
#
# >+ Line-1 So by his Father lost: and this (I take it)
#
# > Line-1 Is the maine Motiue of our Preparations,
# < Line-1    2. Shew me, shew me
#
# >+ Line-1 The Sourse of this our Watch, and the cheefe head
#
# > Line-1 Of this post-hast, and Romage in the Land.
# < Line-1    1. Here I haue a Pilots Thumbe,
#
# > Line-1 Enter Ghost againe.
# < Line-1 Wrackt, as homeward he did come.
#
# > Line-1 But soft, behold: Loe, where it comes againe:
# < Line-1 Drum within.
#
# >+ Line-1 Ile crosse it, though it blast me. Stay Illusion:
#
# > Line-1 If thou hast any sound, or vse of Voyce,
# < Line-1   3. A Drumme, a Drumme:
#
# > Line-1 Speake to me. If there be any good thing to be done,
# < Line-1 Macbeth doth come
#
# >+ Line-1 That may to thee do ease, and grace to me; speak to me.
#
# > Line-1 If thou art priuy to thy Countries Fate
# < Line-1    All. The weyward Sisters, hand in hand,
#
# > Line-1 (Which happily foreknowing may auoyd) Oh speake.
# < Line-1 Posters of the Sea and Land,
#
# > Line-1 Or, if thou hast vp-hoorded in thy life
# < Line-1 Thus doe goe, about, about,
#
# > Line-1 Extorted Treasure in the wombe of Earth,
# < Line-1 Thrice to thine, and thrice to mine,
#
# > Line-1 (For which, they say, you Spirits oft walke in death)
# < Line-1 And thrice againe, to make vp nine.
#
# > Line-1 Speake of it. Stay, and speake. Stop it Marcellus
# < Line-1 Peace, the Charme's wound vp.
#
# <+ Line-1 Enter Macbeth and Banquo.
#
# >+ Line-1    Mar. Shall I strike at it with my Partizan?
#
# > Line-1   Hor. Do, if it will not stand
# < Line-1   Macb. So foule and faire a day I haue not seene
#
# > Line-1    Barn. 'Tis heere
# < Line-1    Banquo. How farre is't call'd to Soris? What are these,
#
# <+ Line-1 So wither'd, and so wilde in their attyre,
#
# > Line-1    Hor. 'Tis heere
# < Line-1 That looke not like th' Inhabitants o'th' Earth,
#
# <+ Line-1 And yet are on't? Liue you, or are you aught
#
# > Line-1    Mar. 'Tis gone.
# < Line-1 That man may question? you seeme to vnderstand me,
#
# <+ Line-1 By each at once her choppie finger laying
#
# > Line-1 Exit Ghost.
# < Line-1 Vpon her skinnie Lips: you should be Women,
#
# <+ Line-1 And yet your Beards forbid me to interprete
#
# > Line-1 We do it wrong, being so Maiesticall
# < Line-1 That you are so
#
# >+ Line-1 To offer it the shew of Violence,
#
# > Line-1 For it is as the Ayre, invulnerable,
# < Line-1    Mac. Speake if you can: what are you?
#
# > Line-1 And our vaine blowes, malicious Mockery
# < Line-1   1. All haile Macbeth, haile to thee Thane of Glamis
#
# > Line-1    Barn. It was about to speake, when the Cocke crew
# < Line-1    2. All haile Macbeth, haile to thee Thane of Cawdor
#
# > Line-1    Hor. And then it started, like a guilty thing
# < Line-1    3. All haile Macbeth, that shalt be King hereafter
#
# >+ Line-1 Vpon a fearfull Summons. I haue heard,
#
# > Line-1 The Cocke that is the Trumpet to the day,
# < Line-1    Banq. Good Sir, why doe you start, and seeme to feare
#
# > Line-1 Doth with his lofty and shrill-sounding Throate
# < Line-1 Things that doe sound so faire? i'th' name of truth
#
# > Line-1 Awake the God of Day: and at his warning,
# < Line-1 Are ye fantasticall, or that indeed
#
# > Line-1 Whether in Sea, or Fire, in Earth, or Ayre,
# < Line-1 Which outwardly ye shew? My Noble Partner
#
# > Line-1 Th' extrauagant, and erring Spirit, hyes
# < Line-1 You greet with present Grace, and great prediction
#
# > Line-1 To his Confine. And of the truth heerein,
# < Line-1 Of Noble hauing, and of Royall hope,
#
# > Line-1 This present Obiect made probation
# < Line-1 That he seemes wrapt withall: to me you speake not.
#
# <+ Line-1 If you can looke into the Seedes of Time,
#
# > Line-1    Mar. It faded on the crowing of the Cocke.
# < Line-1 And say, which Graine will grow, and which will not,
#
# > Line-1 Some sayes, that euer 'gainst that Season comes
# < Line-1 Speake then to me, who neyther begge, nor feare
#
# > Line-1 Wherein our Sauiours Birch is celebrated,
# < Line-1 Your fauors, nor your hate
#
# >+ Line-1 The Bird of Dawning singeth all night long:
#
# > Line-1 And then (they say) no Spirit can walke abroad,
# < Line-1    1. Hayle
#
# >+ Line-1 The nights are wholsome, then no Planets strike,
#
# > Line-1 No Faiery talkes, nor Witch hath power to Charme:
# < Line-1    2. Hayle
#
# >+ Line-1 So hallow'd, and so gracious is the time
#
# <+ Line-1    3. Hayle
#
# >+ Line-1    Hor. So haue I heard, and do in part beleeue it.
#
# > Line-1 But looke, the Morne in Russet mantle clad,
# < Line-1    1. Lesser than Macbeth, and greater
#
# >+ Line-1 Walkes o're the dew of yon high Easterne Hill,
#
# > Line-1 Breake we our Watch vp, and by my aduice
# < Line-1    2. Not so happy, yet much happyer
#
# >+ Line-1 Let vs impart what we haue seene to night
#
# > Line-1 Vnto yong Hamlet. For vpon my life,
# < Line-1    3. Thou shalt get Kings, though thou be none:
#
# > Line-1 This Spirit dumbe to vs, will speake to him:
# < Line-1 So all haile Macbeth, and Banquo
#
# >+ Line-1 Do you consent we shall acquaint him with it,
#
# > Line-1 As needfull in our Loues, fitting our Duty?
# < Line-1    1. Banquo, and Macbeth, all haile
#
# >+ Line-1   Mar. Let do't I pray, and I this morning know
#
# > Line-1 Where we shall finde him most conueniently.
# < Line-1    Macb. Stay you imperfect Speakers, tell me more:
#
# <+ Line-1 By Sinells death, I know I am Thane of Glamis,
#
# > Line-1 Exeunt.
# < Line-1 But how, of Cawdor? the Thane of Cawdor liues
#
# <+ Line-1 A prosperous Gentleman: And to be King,
#
# > Line-1 Scena Secunda.
# < Line-1 Stands not within the prospect of beleefe,
#
# <+ Line-1 No more then to be Cawdor. Say from whence
#
# > Line-1 Enter Claudius King of Denmarke, Gertrude the Queene, Hamlet,
# < Line-1 You owe this strange Intelligence, or why
#
# > Line-1 Polonius,
# < Line-1 Vpon this blasted Heath you stop our way
#
# > Line-1 Laertes, and his Sister Ophelia, Lords Attendant.
# < Line-1 With such Prophetique greeting?
#
# <+ Line-1 Speake, I charge you.
#
# >+ Line-1   King. Though yet of Hamlet our deere Brothers death
#
# > Line-1 The memory be greene: and that it vs befitted
# < Line-1 Witches vanish.
#
# >+ Line-1 To beare our hearts in greefe, and our whole Kingdome
#
# > Line-1 To be contracted in one brow of woe:
# < Line-1   Banq. The Earth hath bubbles, as the Water ha's,
#
# > Line-1 Yet so farre hath Discretion fought with Nature,
# < Line-1 And these are of them: whither are they vanish'd?
#
# > Line-1 That we with wisest sorrow thinke on him,
# < Line-1   Macb. Into the Ayre: and what seem'd corporall,
#
# > Line-1 Together with remembrance of our selues.
# < Line-1 Melted, as breath into the Winde.
#
# > Line-1 Therefore our sometimes Sister, now our Queene,
# < Line-1 Would they had stay'd
#
# >+ Line-1 Th' imperiall Ioyntresse of this warlike State,
#
# > Line-1 Haue we, as 'twere, with a defeated ioy,
# < Line-1    Banq. Were such things here, as we doe speake about?
#
# > Line-1 With one Auspicious, and one Dropping eye,
# < Line-1 Or haue we eaten on the insane Root,
#
# > Line-1 With mirth in Funerall, and with Dirge in Marriage,
# < Line-1 That takes the Reason Prisoner?
#
# > Line-1 In equall Scale weighing Delight and Dole
# < Line-1   Macb. Your Children shall be Kings
#
# >+ Line-1 Taken to Wife; nor haue we heerein barr'd
#
# > Line-1 Your better Wisedomes, which haue freely gone
# < Line-1    Banq. You shall be King
#
# >+ Line-1 With this affaire along, for all our Thankes.
#
# > Line-1 Now followes, that you know young Fortinbras,
# < Line-1    Macb. And Thane of Cawdor too: went it not so?
#
# > Line-1 Holding a weake supposall of our worth;
# < Line-1   Banq. Toth' selfe-same tune and words: who's here?
#
# > Line-1 Or thinking by our late deere Brothers death,
# < Line-1 Enter Rosse and Angus.
#
# >+ Line-1 Our State to be disioynt, and out of Frame,
#
# > Line-1 Colleagued with the dreame of his Aduantage;
# < Line-1   Rosse. The King hath happily receiu'd, Macbeth,
#
# > Line-1 He hath not fayl'd to pester vs with Message,
# < Line-1 The newes of thy successe: and when he reades
#
# > Line-1 Importing the surrender of those Lands
# < Line-1 Thy personall Venture in the Rebels sight,
#
# > Line-1 Lost by his Father: with all Bonds of Law
# < Line-1 His Wonders and his Prayses doe contend,
#
# > Line-1 To our most valiant Brother. So much for him.
# < Line-1 Which should be thine, or his: silenc'd with that,
#
# > Line-1 Enter Voltemand and Cornelius.
# < Line-1 In viewing o're the rest o'th' selfe-same day,
#
# <+ Line-1 He findes thee in the stout Norweyan Rankes,
#
# > Line-1 Now for our selfe, and for this time of meeting
# < Line-1 Nothing afeard of what thy selfe didst make
#
# > Line-1 Thus much the businesse is. We haue heere writ
# < Line-1 Strange Images of death, as thick as Tale
#
# > Line-1 To Norway, Vncle of young Fortinbras,
# < Line-1 Can post with post, and euery one did beare
#
# > Line-1 Who Impotent and Bedrid, scarsely heares
# < Line-1 Thy prayses in his Kingdomes great defence,
#
# > Line-1 Of this his Nephewes purpose, to suppresse
# < Line-1 And powr'd them downe before him
#
# >+ Line-1 His further gate heerein. In that the Leuies,
#
# > Line-1 The Lists, and full proportions are all made
# < Line-1    Ang. Wee are sent,
#
# > Line-1 Out of his subiect: and we heere dispatch
# < Line-1 To giue thee from our Royall Master thanks,
#
# > Line-1 You good Cornelius, and you Voltemand,
# < Line-1 Onely to harrold thee into his sight,
#
# > Line-1 For bearing of this greeting to old Norway,
# < Line-1 Not pay thee
#
# >+ Line-1 Giuing to you no further personall power
#
# > Line-1 To businesse with the King, more then the scope
# < Line-1    Rosse. And for an earnest of a greater Honor,
#
# > Line-1 Of these dilated Articles allow:
# < Line-1 He bad me, from him, call thee Thane of Cawdor:
#
# > Line-1 Farewell, and let your hast commend your duty
# < Line-1 In which addition, haile most worthy Thane,
#
# <+ Line-1 For it is thine
#
# >+ Line-1    Volt. In that, and all things, will we shew our duty
#
# <+ Line-1    Banq. What, can the Deuill speake true?
#
# > Line-1    King. We doubt it nothing, heartily farewell.
# < Line-1   Macb. The Thane of Cawdor liues:
#
# <+ Line-1 Why doe you dresse me in borrowed Robes?
#
# > Line-1 Exit Voltemand and Cornelius.
# < Line-1   Ang. Who was the Thane, liues yet,
#
# <+ Line-1 But vnder heauie Iudgement beares that Life,
#
# > Line-1 And now Laertes, what's the newes with you?
# < Line-1 Which he deserues to loose.
#
# > Line-1 You told vs of some suite. What is't Laertes?
# < Line-1 Whether he was combin'd with those of Norway,
#
# > Line-1 You cannot speake of Reason to the Dane,
# < Line-1 Or did lyne the Rebell with hidden helpe,
#
# > Line-1 And loose your voyce. What would'st thou beg Laertes,
# < Line-1 And vantage; or that with both he labour'd
#
# > Line-1 That shall not be my Offer, not thy Asking?
# < Line-1 In his Countreyes wracke, I know not:
#
# > Line-1 The Head is not more Natiue to the Heart,
# < Line-1 But Treasons Capitall, confess'd, and prou'd,
#
# > Line-1 The Hand more instrumentall to the Mouth,
# < Line-1 Haue ouerthrowne him
#
# >+ Line-1 Then is the Throne of Denmarke to thy Father.
#
# > Line-1 What would'st thou haue Laertes?
# < Line-1    Macb. Glamys, and Thane of Cawdor:
#
# > Line-1   Laer. Dread my Lord,
# < Line-1 The greatest is behinde. Thankes for your paines.
#
# > Line-1 Your leaue and fauour to returne to France,
# < Line-1 Doe you not hope your Children shall be Kings,
#
# > Line-1 From whence, though willingly I came to Denmarke
# < Line-1 When those that gaue the Thane of Cawdor to me,
#
# > Line-1 To shew my duty in your Coronation,
# < Line-1 Promis'd no lesse to them
#
# >+ Line-1 Yet now I must confesse, that duty done,
#
# > Line-1 My thoughts and wishes bend againe towards France,
# < Line-1    Banq. That trusted home,
#
# > Line-1 And bow them to your gracious leaue and pardon
# < Line-1 Might yet enkindle you vnto the Crowne,
#
# <+ Line-1 Besides the Thane of Cawdor. But 'tis strange:
#
# > Line-1    King. Haue you your Fathers leaue?
# < Line-1 And oftentimes, to winne vs to our harme,
#
# > Line-1 What sayes Pollonius?
# < Line-1 The Instruments of Darknesse tell vs Truths,
#
# > Line-1   Pol. He hath my Lord:
# < Line-1 Winne vs with honest Trifles, to betray's
#
# > Line-1 I do beseech you giue him leaue to go
# < Line-1 In deepest consequence.
#
# <+ Line-1 Cousins, a word, I pray you
#
# >+ Line-1    King. Take thy faire houre Laertes, time be thine,
#
# > Line-1 And thy best graces spend it at thy will:
# < Line-1    Macb. Two Truths are told,
#
# > Line-1 But now my Cosin Hamlet, and my Sonne?
# < Line-1 As happy Prologues to the swelling Act
#
# > Line-1   Ham. A little more then kin, and lesse then kinde
# < Line-1 Of the Imperiall Theame. I thanke you Gentlemen:
#
# <+ Line-1 This supernaturall solliciting
#
# > Line-1    King. How is it that the Clouds still hang on you?
# < Line-1 Cannot be ill; cannot be good.
#
# > Line-1   Ham. Not so my Lord, I am too much i'th' Sun
# < Line-1 If ill? why hath it giuen me earnest of successe,
#
# <+ Line-1 Commencing in a Truth? I am Thane of Cawdor.
#
# > Line-1    Queen. Good Hamlet cast thy nightly colour off,
# < Line-1 If good? why doe I yeeld to that suggestion,
#
# > Line-1 And let thine eye looke like a Friend on Denmarke.
# < Line-1 Whose horrid Image doth vnfixe my Heire,
#
# > Line-1 Do not for euer with thy veyled lids
# < Line-1 And make my seated Heart knock at my Ribbes,
#
# > Line-1 Seeke for thy Noble Father in the dust;
# < Line-1 Against the vse of Nature? Present Feares
#
# > Line-1 Thou know'st 'tis common, all that liues must dye,
# < Line-1 Are lesse then horrible Imaginings:
#
# > Line-1 Passing through Nature, to Eternity
# < Line-1 My Thought, whose Murther yet is but fantasticall,
#
# <+ Line-1 Shakes so my single state of Man,
#
# > Line-1    Ham. I Madam, it is common
# < Line-1 That Function is smother'd in surmise,
#
# <+ Line-1 And nothing is, but what is not
#
# >+ Line-1    Queen. If it be;
#
# > Line-1 Why seemes it so particular with thee
# < Line-1    Banq. Looke how our Partner's rapt
#
# > Line-1    Ham. Seemes Madam? Nay, it is: I know not Seemes:
# < Line-1    Macb. If Chance will haue me King,
#
# > Line-1 'Tis not alone my Inky Cloake (good Mother)
# < Line-1 Why Chance may Crowne me,
#
# > Line-1 Nor Customary suites of solemne Blacke,
# < Line-1 Without my stirre
#
# >+ Line-1 Nor windy suspiration of forc'd breath,
#
# > Line-1 No, nor the fruitfull Riuer in the Eye,
# < Line-1    Banq. New Honors come vpon him
#
# > Line-1 Nor the deiected hauiour of the Visage,
# < Line-1 Like our strange Garments, cleaue not to their mould,
#
# > Line-1 Together with all Formes, Moods, shewes of Griefe,
# < Line-1 But with the aid of vse
#
# >+ Line-1 That can denote me truly. These indeed Seeme,
#
# > Line-1 For they are actions that a man might play:
# < Line-1    Macb. Come what come may,
#
# > Line-1 But I haue that Within, which passeth show;
# < Line-1 Time, and the Houre, runs through the roughest Day
#
# >+ Line-1 These, but the Trappings, and the Suites of woe
#
# <+ Line-1    Banq. Worthy Macbeth, wee stay vpon your leysure
#
# >+ Line-1    King. 'Tis sweet and commendable
#
# > Line-1 In your Nature Hamlet,
# < Line-1    Macb. Giue me your fauour:
#
# > Line-1 To giue these mourning duties to your Father:
# < Line-1 My dull Braine was wrought with things forgotten.
#
# > Line-1 But you must know, your Father lost a Father,
# < Line-1 Kinde Gentlemen, your paines are registred,
#
# > Line-1 That Father lost, lost his, and the Suruiuer bound
# < Line-1 Where euery day I turne the Leafe,
#
# > Line-1 In filiall Obligation, for some terme
# < Line-1 To reade them.
#
# > Line-1 To do obsequious Sorrow. But to perseuer
# < Line-1 Let vs toward the King: thinke vpon
#
# > Line-1 In obstinate Condolement, is a course
# < Line-1 What hath chanc'd: and at more time,
#
# > Line-1 Of impious stubbornnesse. 'Tis vnmanly greefe,
# < Line-1 The Interim hauing weigh'd it, let vs speake
#
# > Line-1 It shewes a will most incorrect to Heauen,
# < Line-1 Our free Hearts each to other
#
# >+ Line-1 A Heart vnfortified, a Minde impatient,
#
# > Line-1 An Vnderstanding simple, and vnschool'd:
# < Line-1    Banq. Very gladly
#
# >+ Line-1 For, what we know must be, and is as common
#
# > Line-1 As any the most vulgar thing to sence,
# < Line-1    Macb. Till then enough:
#
# > Line-1 Why should we in our peeuish Opposition
# < Line-1 Come friends.
#
# >+ Line-1 Take it to heart? Fye, 'tis a fault to Heauen,
#
# > Line-1 A fault against the Dead, a fault to Nature,
# < Line-1 Exeunt.
#
# >+ Line-1 To Reason most absurd, whose common Theame
#
# >+ Line-1 Is death of Fathers, and who still hath cried,
#
# > Line-1 From the first Coarse, till he that dyed to day,
# < Line-1 Scena Quarta.
#
# >+ Line-1 This must be so. We pray you throw to earth
#
# > Line-1 This vnpreuayling woe, and thinke of vs
# < Line-1 Flourish. Enter King, Lenox, Malcolme, Donalbaine, and
#
# > Line-1 As of a Father; For let the world take note,
# < Line-1 Attendants.
#
# >+ Line-1 You are the most immediate to our Throne,
#
# > Line-1 And with no lesse Nobility of Loue,
# < Line-1   King. Is execution done on Cawdor?
#
# > Line-1 Then that which deerest Father beares his Sonne,
# < Line-1 Or not those in Commission yet return'd?
#
# > Line-1 Do I impart towards you. For your intent
# < Line-1   Mal. My Liege, they are not yet come back.
#
# > Line-1 In going backe to Schoole in Wittenberg,
# < Line-1 But I haue spoke with one that saw him die:
#
# > Line-1 It is most retrograde to our desire:
# < Line-1 Who did report, that very frankly hee
#
# > Line-1 And we beseech you, bend you to remaine
# < Line-1 Confess'd his Treasons, implor'd your Highnesse Pardon,
#
# > Line-1 Heere in the cheere and comfort of our eye,
# < Line-1 And set forth a deepe Repentance:
#
# > Line-1 Our cheefest Courtier Cosin, and our Sonne
# < Line-1 Nothing in his Life became him,
#
# <+ Line-1 Like the leauing it. Hee dy'de,
#
# > Line-1    Qu. Let not thy Mother lose her Prayers Hamlet:
# < Line-1 As one that had beene studied in his death,
#
# > Line-1 I prythee stay with vs, go not to Wittenberg
# < Line-1 To throw away the dearest thing he ow'd,
#
# <+ Line-1 As 'twere a carelesse Trifle
#
# >+ Line-1    Ham. I shall in all my best
#
# > Line-1 Obey you Madam
# < Line-1    King. There's no Art,
#
# <+ Line-1 To finde the Mindes construction in the Face.
#
# > Line-1    King. Why 'tis a louing, and a faire Reply,
# < Line-1 He was a Gentleman, on whom I built
#
# > Line-1 Be as our selfe in Denmarke. Madam come,
# < Line-1 An absolute Trust.
#
# > Line-1 This gentle and vnforc'd accord of Hamlet
# < Line-1 Enter Macbeth, Banquo, Rosse, and Angus.
#
# >+ Line-1 Sits smiling to my heart; in grace whereof,
#
# > Line-1 No iocond health that Denmarke drinkes to day,
# < Line-1 O worthyest Cousin,
#
# > Line-1 But the great Cannon to the Clowds shall tell,
# < Line-1 The sinne of my Ingratitude euen now
#
# > Line-1 And the Kings Rouce, the Heauens shall bruite againe,
# < Line-1 Was heauie on me. Thou art so farre before,
#
# > Line-1 Respeaking earthly Thunder. Come away.
# < Line-1 That swiftest Wing of Recompence is slow,
#
# <+ Line-1 To ouertake thee. Would thou hadst lesse deseru'd,
#
# > Line-1 Exeunt.
# < Line-1 That the proportion both of thanks, and payment,
#
# <+ Line-1 Might haue beene mine: onely I haue left to say,
#
# > Line-1 Manet Hamlet.
# < Line-1 More is thy due, then more then all can pay
#
# > Line-1   Ham. Oh that this too too solid Flesh, would melt,
# < Line-1    Macb. The seruice, and the loyaltie I owe,
#
# > Line-1 Thaw, and resolue it selfe into a Dew:
# < Line-1 In doing it, payes it selfe.
#
# > Line-1 Or that the Euerlasting had not fixt
# < Line-1 Your Highnesse part, is to receiue our Duties:
#
# > Line-1 His Cannon 'gainst Selfe-slaughter. O God, O God!
# < Line-1 And our Duties are to your Throne, and State,
#
# > Line-1 How weary, stale, flat, and vnprofitable
# < Line-1 Children, and Seruants; which doe but what they should,
#
# > Line-1 Seemes to me all the vses of this world?
# < Line-1 By doing euery thing safe toward your Loue
#
# > Line-1 Fie on't? Oh fie, fie, 'tis an vnweeded Garden
# < Line-1 And Honor
#
# >+ Line-1 That growes to Seed: Things rank, and grosse in Nature
#
# > Line-1 Possesse it meerely. That it should come to this:
# < Line-1    King. Welcome hither:
#
# > Line-1 But two months dead: Nay, not so much; not two,
# < Line-1 I haue begun to plant thee, and will labour
#
# > Line-1 So excellent a King, that was to this
# < Line-1 To make thee full of growing. Noble Banquo,
#
# > Line-1 Hiperion to a Satyre: so louing to my Mother,
# < Line-1 That hast no lesse deseru'd, nor must be knowne
#
# > Line-1 That he might not beteene the windes of heauen
# < Line-1 No lesse to haue done so: Let me enfold thee,
#
# > Line-1 Visit her face too roughly. Heauen and Earth
# < Line-1 And hold thee to my Heart
#
# >+ Line-1 Must I remember: why she would hang on him,
#
# > Line-1 As if encrease of Appetite had growne
# < Line-1    Banq. There if I grow,
#
# > Line-1 By what is fed on; and yet within a month?
# < Line-1 The Haruest is your owne
#
# >+ Line-1 Let me not thinke on't: Frailty, thy name is woman.
#
# > Line-1 A little Month, or ere those shooes were old,
# < Line-1    King. My plenteous Ioyes,
#
# > Line-1 With which she followed my poore Fathers body
# < Line-1 Wanton in fulnesse, seeke to hide themselues
#
# > Line-1 Like Niobe, all teares. Why she, euen she.
# < Line-1 In drops of sorrow. Sonnes, Kinsmen, Thanes,
#
# > Line-1 (O Heauen! A beast that wants discourse of Reason
# < Line-1 And you whose places are the nearest, know,
#
# > Line-1 Would haue mourn'd longer) married with mine Vnkle,
# < Line-1 We will establish our Estate vpon
#
# > Line-1 My Fathers Brother: but no more like my Father,
# < Line-1 Our eldest, Malcolme, whom we name hereafter,
#
# > Line-1 Then I to Hercules. Within a Moneth?
# < Line-1 The Prince of Cumberland: which Honor must
#
# > Line-1 Ere yet the salt of most vnrighteous Teares
# < Line-1 Not vnaccompanied, inuest him onely,
#
# > Line-1 Had left the flushing of her gauled eyes,
# < Line-1 But signes of Noblenesse, like Starres, shall shine
#
# > Line-1 She married. O most wicked speed, to post
# < Line-1 On all deseruers. From hence to Envernes,
#
# > Line-1 With such dexterity to Incestuous sheets:
# < Line-1 And binde vs further to you
#
# >+ Line-1 It is not, nor it cannot come to good.
#
# > Line-1 But breake my heart, for I must hold my tongue.
# < Line-1    Macb. The Rest is Labor, which is not vs'd for you:
#
# > Line-1 Enter Horatio, Barnardo, and Marcellus.
# < Line-1 Ile be my selfe the Herbenger, and make ioyfull
#
# <+ Line-1 The hearing of my Wife, with your approach:
#
# > Line-1   Hor. Haile to your Lordship
# < Line-1 So humbly take my leaue
#
# > Line-1    Ham. I am glad to see you well:
# < Line-1    King. My worthy Cawdor
#
# >+ Line-1 Horatio, or I do forget my selfe
#
# <+ Line-1    Macb. The Prince of Cumberland: that is a step,
#
# > Line-1    Hor. The same my Lord,
# < Line-1 On which I must fall downe, or else o're-leape,
#
# > Line-1 And your poore Seruant euer
# < Line-1 For in my way it lyes. Starres hide your fires,
#
# <+ Line-1 Let not Light see my black and deepe desires:
#
# > Line-1    Ham. Sir my good friend,
# < Line-1 The Eye winke at the Hand: yet let that bee,
#
# > Line-1 Ile change that name with you:
# < Line-1 Which the Eye feares, when it is done to see.
#
# > Line-1 And what make you from Wittenberg Horatio?
# < Line-1 Enter.
#
# >+ Line-1 Marcellus
#
# <+ Line-1   King. True worthy Banquo: he is full so valiant,
#
# > Line-1    Mar. My good Lord
# < Line-1 And in his commendations, I am fed:
#
# <+ Line-1 It is a Banquet to me. Let's after him,
#
# > Line-1    Ham. I am very glad to see you: good euen Sir.
# < Line-1 Whose care is gone before, to bid vs welcome:
#
# > Line-1 But what in faith make you from Wittemberge?
# < Line-1 It is a peerelesse Kinsman.
#
# >+ Line-1   Hor. A truant disposition, good my Lord
#
# <+ Line-1 Flourish. Exeunt.
#
# >+ Line-1    Ham. I would not haue your Enemy say so;
#
# >+ Line-1 Nor shall you doe mine eare that violence,
#
# > Line-1 To make it truster of your owne report
# < Line-1 Scena Quinta.
#
# >+ Line-1 Against your selfe. I know you are no Truant:
#
# > Line-1 But what is your affaire in Elsenour?
# < Line-1 Enter Macbeths Wife alone with a Letter.
#
# >+ Line-1 Wee'l teach you to drinke deepe, ere you depart
#
# <+ Line-1   Lady. They met me in the day of successe: and I haue
#
# > Line-1    Hor. My Lord, I came to see your Fathers Funerall
# < Line-1 learn'd by the perfect'st report, they haue more in them, then
#
# <+ Line-1 mortall knowledge. When I burnt in desire to question them
#
# > Line-1    Ham. I pray thee doe not mock me (fellow Student)
# < Line-1 further, they made themselues Ayre, into which they vanish'd.
#
# > Line-1 I thinke it was to see my Mothers Wedding
# < Line-1 Whiles I stood rapt in the wonder of it, came Missiues from
#
# <+ Line-1 the King, who all-hail'd me Thane of Cawdor, by which Title
#
# > Line-1    Hor. Indeed my Lord, it followed hard vpon
# < Line-1 before, these weyward Sisters saluted me, and referr'd me to
#
# <+ Line-1 the comming on of time, with haile King that shalt be. This
#
# > Line-1    Ham. Thrift thrift Horatio: the Funerall Bakt-meats
# < Line-1 haue I thought good to deliuer thee (my dearest Partner of
#
# > Line-1 Did coldly furnish forth the Marriage Tables;
# < Line-1 Greatnesse) that thou might'st not loose the dues of reioycing
#
# > Line-1 Would I had met my dearest foe in heauen,
# < Line-1 by being ignorant of what Greatnesse is promis'd thee. Lay
#
# > Line-1 Ere I had euer seene that day Horatio.
# < Line-1 it to thy heart and farewell.
#
# > Line-1 My father, me thinkes I see my father
# < Line-1 Glamys thou art, and Cawdor, and shalt be
#
# <+ Line-1 What thou art promis'd: yet doe I feare thy Nature,
#
# > Line-1    Hor. Oh where my Lord?
# < Line-1 It is too full o'th' Milke of humane kindnesse,
#
# > Line-1   Ham. In my minds eye (Horatio)
# < Line-1 To catch the neerest way. Thou would'st be great,
#
# > Line-1   Hor. I saw him once; he was a goodly King
# < Line-1 Art not without Ambition, but without
#
# <+ Line-1 The illnesse should attend it. What thou would'st highly,
#
# > Line-1    Ham. He was a man, take him for all in all:
# < Line-1 That would'st thou holily: would'st not play false,
#
# > Line-1 I shall not look vpon his like againe
# < Line-1 And yet would'st wrongly winne.
#
# <+ Line-1 Thould'st haue, great Glamys, that which cryes,
#
# > Line-1    Hor. My Lord, I thinke I saw him yesternight
# < Line-1 Thus thou must doe, if thou haue it;
#
# <+ Line-1 And that which rather thou do'st feare to doe,
#
# > Line-1    Ham. Saw? Who?
# < Line-1 Then wishest should be vndone. High thee hither,
#
# > Line-1   Hor. My Lord, the King your Father
# < Line-1 That I may powre my Spirits in thine Eare,
#
# <+ Line-1 And chastise with the valour of my Tongue
#
# > Line-1    Ham. The King my Father?
# ...
# >+ Line-1 know him: he hath much Land, and fertile; let a Beast
#
# >+ Line-1 be Lord of Beasts, and his Crib shall stand at the Kings
#
# >+ Line-1 Messe; 'tis a Chowgh; but as I saw spacious in the possession
#
# >+ Line-1 of dirt
#
# >+ Line-1    Osr. Sweet Lord, if your friendship were at leysure,
#
# >+ Line-1 I should impart a thing to you from his Maiesty
#
# >+ Line-1    Ham. I will receiue it with all diligence of spirit; put
#
# >+ Line-1 your Bonet to his right vse, 'tis for the head
#
# >+ Line-1    Osr. I thanke your Lordship, 'tis very hot
#
# >+ Line-1    Ham. No, beleeue mee 'tis very cold, the winde is
#
# >+ Line-1 Northerly
#
# >+ Line-1    Osr. It is indifferent cold my Lord indeed
#
# >+ Line-1    Ham. Mee thinkes it is very soultry, and hot for my
#
# >+ Line-1 Complexion
#
# >+ Line-1    Osr. Exceedingly, my Lord, it is very soultry, as 'twere
#
# >+ Line-1 I cannot tell how: but my Lord, his Maiesty bad me signifie
#
# >+ Line-1 to you, that he ha's laid a great wager on your head:
#
# >+ Line-1 Sir, this is the matter
#
# >+ Line-1    Ham. I beseech you remember
#
# >+ Line-1    Osr. Nay, in good faith, for mine ease in good faith:
#
# >+ Line-1 Sir, you are not ignorant of what excellence Laertes is at
#
# >+ Line-1 his weapon
#
# >+ Line-1    Ham. What's his weapon?
#
# >+ Line-1   Osr. Rapier and dagger
#
# >+ Line-1    Ham. That's two of his weapons; but well
#
# >+ Line-1    Osr. The sir King ha's wag'd with him six Barbary horses,
#
# >+ Line-1 against the which he impon'd as I take it, sixe French
#
# >+ Line-1 Rapiers and Poniards, with their assignes, as Girdle,
#
# >+ Line-1 Hangers or so: three of the Carriages infaith are very
#
# >+ Line-1 deare to fancy, very responsiue to the hilts, most delicate
#
# >+ Line-1 carriages, and of very liberall conceit
#
# >+ Line-1    Ham. What call you the Carriages?
#
# >+ Line-1   Osr. The Carriages Sir, are the hangers
#
# >+ Line-1    Ham. The phrase would bee more Germaine to the
#
# >+ Line-1 matter: If we could carry Cannon by our sides; I would
#
# >+ Line-1 it might be Hangers till then; but on sixe Barbary Horses
#
# >+ Line-1 against sixe French Swords: their Assignes, and three
#
# >+ Line-1 liberall conceited Carriages, that's the French but against
#
# >+ Line-1 the Danish; why is this impon'd as you call it?
#
# >+ Line-1   Osr. The King Sir, hath laid that in a dozen passes betweene
#
# >+ Line-1 you and him, hee shall not exceed you three hits;
#
# >+ Line-1 He hath one twelue for mine, and that would come to
#
# >+ Line-1 imediate tryall, if your Lordship would vouchsafe the
#
# >+ Line-1 Answere
#
# >+ Line-1    Ham. How if I answere no?
#
# >+ Line-1   Osr. I meane my Lord, the opposition of your person
#
# >+ Line-1 in tryall
#
# >+ Line-1    Ham. Sir, I will walke heere in the Hall; if it please
#
# >+ Line-1 his Maiestie, 'tis the breathing time of day with me; let
#
# >+ Line-1 the Foyles bee brought, the Gentleman willing, and the
#
# >+ Line-1 King hold his purpose; I will win for him if I can: if
#
# >+ Line-1 not, Ile gaine nothing but my shame, and the odde hits
#
# >+ Line-1    Osr. Shall I redeliuer you ee'n so?
#
# >+ Line-1   Ham. To this effect Sir, after what flourish your nature
#
# >+ Line-1 will
#
# >+ Line-1    Osr. I commend my duty to your Lordship
#
# >+ Line-1    Ham. Yours, yours; hee does well to commend it
#
# >+ Line-1 himselfe, there are no tongues else for's tongue
#
# >+ Line-1    Hor. This Lapwing runs away with the shell on his
#
# >+ Line-1 head
#
# >+ Line-1    Ham. He did Complie with his Dugge before hee
#
# >+ Line-1 suck't it: thus had he and mine more of the same Beauty
#
# >+ Line-1 that I know the drossie age dotes on; only got the tune of
#
# >+ Line-1 the time, and outward habite of encounter, a kinde of
#
# >+ Line-1 yesty collection, which carries them through & through
#
# >+ Line-1 the most fond and winnowed opinions; and doe but blow
#
# >+ Line-1 them to their tryalls: the Bubbles are out
#
# >+ Line-1    Hor. You will lose this wager, my Lord
#
# >+ Line-1    Ham. I doe not thinke so, since he went into France,
#
# >+ Line-1 I haue beene in continuall practice; I shall winne at the
#
# >+ Line-1 oddes: but thou wouldest not thinke how all heere about
#
# >+ Line-1 my heart: but it is no matter
#
# >+ Line-1    Hor. Nay, good my Lord
#
# >+ Line-1    Ham. It is but foolery; but it is such a kinde of
#
# >+ Line-1 gain-giuing as would perhaps trouble a woman
#
# >+ Line-1    Hor. If your minde dislike any thing, obey. I will forestall
#
# >+ Line-1 their repaire hither, and say you are not fit
#
# >+ Line-1    Ham. Not a whit, we defie Augury; there's a speciall
#
# >+ Line-1 Prouidence in the fall of a sparrow. If it be now, 'tis not
#
# >+ Line-1 to come: if it bee not to come, it will bee now: if it
#
# >+ Line-1 be not now; yet it will come; the readinesse is all, since no
#
# >+ Line-1 man ha's ought of what he leaues. What is't to leaue betimes?
#
# >+ Line-1 Enter King, Queene, Laertes and Lords, with other Attendants with
#
# >+ Line-1 Foyles,
#
# >+ Line-1 and Gauntlets, a Table and Flagons of Wine on it.
#
# >+ Line-1   Kin. Come Hamlet, come, and take this hand from me
#
# >+ Line-1    Ham. Giue me your pardon Sir, I'ue done you wrong,
#
# >+ Line-1 But pardon't as you are a Gentleman.
#
# >+ Line-1 This presence knowes,
#
# >+ Line-1 And you must needs haue heard how I am punisht
#
# >+ Line-1 With sore distraction? What I haue done
#
# >+ Line-1 That might your nature honour, and exception
#
# >+ Line-1 Roughly awake, I heere proclaime was madnesse:
#
# >+ Line-1 Was't Hamlet wrong'd Laertes? Neuer Hamlet.
#
# >+ Line-1 If Hamlet from himselfe be tane away:
#
# >+ Line-1 And when he's not himselfe, do's wrong Laertes,
#
# >+ Line-1 Then Hamlet does it not, Hamlet denies it:
#
# >+ Line-1 Who does it then? His Madnesse? If't be so,
#
# >+ Line-1 Hamlet is of the Faction that is wrong'd,
#
# >+ Line-1 His madnesse is poore Hamlets Enemy.
#
# >+ Line-1 Sir, in this Audience,
#
# >+ Line-1 Let my disclaiming from a purpos'd euill,
#
# >+ Line-1 Free me so farre in your most generous thoughts,
#
# >+ Line-1 That I haue shot mine Arrow o're the house,
#
# >+ Line-1 And hurt my Mother
#
# >+ Line-1    Laer. I am satisfied in Nature,
#
# >+ Line-1 Whose motiue in this case should stirre me most
#
# >+ Line-1 To my Reuenge. But in my termes of Honor
#
# >+ Line-1 I stand aloofe, and will no reconcilement,
#
# >+ Line-1 Till by some elder Masters of knowne Honor,
#
# >+ Line-1 I haue a voyce, and president of peace
#
# >+ Line-1 To keepe my name vngorg'd. But till that time,
#
# >+ Line-1 I do receiue your offer'd loue like loue,
#
# >+ Line-1 And wil not wrong it
#
# >+ Line-1    Ham. I do embrace it freely,
#
# >+ Line-1 And will this Brothers wager frankely play.
#
# >+ Line-1 Giue vs the Foyles: Come on
#
# >+ Line-1    Laer. Come one for me
#
# >+ Line-1    Ham. Ile be your foile Laertes, in mine ignorance,
#
# >+ Line-1 Your Skill shall like a Starre i'th' darkest night,
#
# >+ Line-1 Sticke fiery off indeede
#
# >+ Line-1    Laer. You mocke me Sir
#
# >+ Line-1    Ham. No by this hand
#
# >+ Line-1    King. Giue them the Foyles yong Osricke,
#
# >+ Line-1 Cousen Hamlet, you know the wager
#
# >+ Line-1    Ham. Verie well my Lord,
#
# >+ Line-1 Your Grace hath laide the oddes a'th' weaker side
#
# >+ Line-1    King. I do not feare it,
#
# >+ Line-1 I haue seene you both:
#
# >+ Line-1 But since he is better'd, we haue therefore oddes
#
# >+ Line-1    Laer. This is too heauy,
#
# >+ Line-1 Let me see another
#
# >+ Line-1    Ham. This likes me well,
#
# >+ Line-1 These Foyles haue all a length.
#
# >+ Line-1 Prepare to play.
#
# >+ Line-1   Osricke. I my good Lord
#
# >+ Line-1    King. Set me the Stopes of wine vpon that Table:
#
# >+ Line-1 If Hamlet giue the first, or second hit,
#
# >+ Line-1 Or quit in answer of the third exchange,
#
# >+ Line-1 Let all the Battlements their Ordinance fire,
#
# >+ Line-1 The King shal drinke to Hamlets better breath,
#
# >+ Line-1 And in the Cup an vnion shal he throw
#
# >+ Line-1 Richer then that, which foure successiue Kings
#
# >+ Line-1 In Denmarkes Crowne haue worne.
#
# >+ Line-1 Giue me the Cups,
#
# >+ Line-1 And let the Kettle to the Trumpets speake,
#
# >+ Line-1 The Trumpet to the Cannoneer without,
#
# >+ Line-1 The Cannons to the Heauens, the Heauen to Earth,
#
# >+ Line-1 Now the King drinkes to Hamlet. Come, begin,
#
# >+ Line-1 And you the Iudges beare a wary eye
#
# >+ Line-1    Ham. Come on sir
#
# >+ Line-1    Laer. Come on sir.
#
# >+ Line-1 They play.
#
# >+ Line-1   Ham. One
#
# >+ Line-1    Laer. No
#
# >+ Line-1    Ham. Iudgement
#
# >+ Line-1    Osr. A hit, a very palpable hit
#
# >+ Line-1    Laer. Well: againe
#
# >+ Line-1    King. Stay, giue me drinke.
#
# >+ Line-1 Hamlet, this Pearle is thine,
#
# >+ Line-1 Here's to thy health. Giue him the cup,
#
# >+ Line-1 Trumpets sound, and shot goes off.
#
# >+ Line-1   Ham. Ile play this bout first, set by a-while.
#
# >+ Line-1 Come: Another hit; what say you?
#
# >+ Line-1   Laer. A touch, a touch, I do confesse
#
# >+ Line-1    King. Our Sonne shall win
#
# >+ Line-1    Qu. He's fat, and scant of breath.
#
# >+ Line-1 Heere's a Napkin, rub thy browes,
#
# >+ Line-1 The Queene Carowses to thy fortune, Hamlet
#
# >+ Line-1    Ham. Good Madam
#
# >+ Line-1    King. Gertrude, do not drinke
#
# >+ Line-1    Qu. I will my Lord;
#
# >+ Line-1 I pray you pardon me
#
# >+ Line-1    King. It is the poyson'd Cup, it is too late
#
# >+ Line-1    Ham. I dare not drinke yet Madam,
#
# >+ Line-1 By and by
#
# >+ Line-1    Qu. Come, let me wipe thy face
#
# >+ Line-1    Laer. My Lord, Ile hit him now
#
# >+ Line-1    King. I do not thinke't
#
# >+ Line-1    Laer. And yet 'tis almost 'gainst my conscience
#
# >+ Line-1    Ham. Come for the third.
#
# >+ Line-1 Laertes, you but dally,
#
# >+ Line-1 I pray you passe with your best violence,
#
# >+ Line-1 I am affear'd you make a wanton of me
#
# >+ Line-1    Laer. Say you so? Come on.
#
# >+ Line-1 Play.
#
# >+ Line-1   Osr. Nothing neither way
#
# >+ Line-1    Laer. Haue at you now.
#
# >+ Line-1 In scuffling they change Rapiers.
#
# >+ Line-1   King. Part them, they are incens'd
#
# >+ Line-1    Ham. Nay come, againe
#
# >+ Line-1    Osr. Looke to the Queene there hoa
#
# >+ Line-1    Hor. They bleed on both sides. How is't my Lord?
#
# >+ Line-1   Osr. How is't Laertes?
#
# >+ Line-1   Laer. Why as a Woodcocke
#
# >+ Line-1 To mine Sprindge, Osricke,
#
# >+ Line-1 I am iustly kill'd with mine owne Treacherie
#
# >+ Line-1    Ham. How does the Queene?
#
# >+ Line-1   King. She sounds to see them bleede
#
# >+ Line-1    Qu. No, no, the drinke, the drinke.
#
# >+ Line-1 Oh my deere Hamlet, the drinke, the drinke,
#
# >+ Line-1 I am poyson'd
#
# >+ Line-1    Ham. Oh Villany! How? Let the doore be lock'd.
#
# >+ Line-1 Treacherie, seeke it out
#
# >+ Line-1    Laer. It is heere Hamlet.
#
# >+ Line-1 Hamlet, thou art slaine,
#
# >+ Line-1 No Medicine in the world can do thee good.
#
# >+ Line-1 In thee, there is not halfe an houre of life;
#
# >+ Line-1 The Treacherous Instrument is in thy hand,
#
# >+ Line-1 Vnbated and envenom'd: the foule practise
#
# >+ Line-1 Hath turn'd it selfe on me. Loe, heere I lye,
#
# >+ Line-1 Neuer to rise againe: Thy Mothers poyson'd:
#
# >+ Line-1 I can no more, the King, the King's too blame
#
# >+ Line-1    Ham. The point envenom'd too,
#
# >+ Line-1 Then venome to thy worke.
#
# >+ Line-1 Hurts the King.
#
# >+ Line-1   All. Treason, Treason
#
# >+ Line-1    King. O yet defend me Friends, I am but hurt
#
# >+ Line-1    Ham. Heere thou incestuous, murdrous,
#
# >+ Line-1 Damned Dane,
#
# >+ Line-1 Drinke off this Potion: Is thy Vnion heere?
#
# >+ Line-1 Follow my Mother.
#
# >+ Line-1 King Dyes.
#
# >+ Line-1   Laer. He is iustly seru'd.
#
# >+ Line-1 It is a poyson temp'red by himselfe:
#
# >+ Line-1 Exchange forgiuenesse with me, Noble Hamlet;
#
# >+ Line-1 Mine and my Fathers death come not vpon thee,
#
# >+ Line-1 Nor thine on me.
#
# >+ Line-1 Dyes.
#
# >+ Line-1   Ham. Heauen make thee free of it, I follow thee.
#
# >+ Line-1 I am dead Horatio, wretched Queene adiew,
#
# >+ Line-1 You that looke pale, and tremble at this chance,
#
# >+ Line-1 That are but Mutes or audience to this acte:
#
# >+ Line-1 Had I but time (as this fell Sergeant death
#
# >+ Line-1 Is strick'd in his Arrest) oh I could tell you.
#
# >+ Line-1 But let it be: Horatio, I am dead,
#
# >+ Line-1 Thou liu'st, report me and my causes right
#
# >+ Line-1 To the vnsatisfied
#
# >+ Line-1    Hor. Neuer beleeue it.
#
# >+ Line-1 I am more an Antike Roman then a Dane:
#
# >+ Line-1 Heere's yet some Liquor left
#
# >+ Line-1    Ham. As th'art a man, giue me the Cup.
#
# >+ Line-1 Let go, by Heauen Ile haue't.
#
# >+ Line-1 Oh good Horatio, what a wounded name,
#
# >+ Line-1 (Things standing thus vnknowne) shall liue behind me.
#
# >+ Line-1 If thou did'st euer hold me in thy heart,
#
# >+ Line-1 Absent thee from felicitie awhile,
#
# >+ Line-1 And in this harsh world draw thy breath in paine,
#
# >+ Line-1 To tell my Storie.
#
# >+ Line-1 March afarre off, and shout within.
#
# >+ Line-1 What warlike noyse is this?
#
# >+ Line-1 Enter Osricke.
#
# >+ Line-1   Osr. Yong Fortinbras, with conquest come fro[m] Poland
#
# >+ Line-1 To th' Ambassadors of England giues this warlike volly
#
# >+ Line-1    Ham. O I dye Horatio:
#
# >+ Line-1 The potent poyson quite ore-crowes my spirit,
#
# >+ Line-1 I cannot liue to heare the Newes from England,
#
# >+ Line-1 But I do prophesie th' election lights
#
# >+ Line-1 On Fortinbras, he ha's my dying voyce,
#
# >+ Line-1 So tell him with the occurrents more and lesse,
#
# >+ Line-1 Which haue solicited. The rest is silence. O, o, o, o.
#
# >+ Line-1 Dyes
#
# >+ Line-1   Hora. Now cracke a Noble heart:
#
# >+ Line-1 Goodnight sweet Prince,
#
# >+ Line-1 And flights of Angels sing thee to thy rest,
#
# >+ Line-1 Why do's the Drumme come hither?
#
# >+ Line-1 Enter Fortinbras and English Ambassador, with Drumme, Colours,
#
# >+ Line-1 and
#
# >+ Line-1 Attendants.
#
# >+ Line-1   Fortin. Where is this sight?
#
# >+ Line-1   Hor. What is it ye would see;
#
# >+ Line-1 If ought of woe, or wonder, cease your search
#
# >+ Line-1    For. His quarry cries on hauocke. Oh proud death,
#
# >+ Line-1 What feast is toward in thine eternall Cell.
#
# >+ Line-1 That thou so many Princes, at a shoote,
#
# >+ Line-1 So bloodily hast strooke
#
# >+ Line-1    Amb. The sight is dismall,
#
# >+ Line-1 And our affaires from England come too late,
#
# >+ Line-1 The eares are senselesse that should giue vs hearing,
#
# >+ Line-1 To tell him his command'ment is fulfill'd,
#
# >+ Line-1 That Rosincrance and Guildensterne are dead:
#
# >+ Line-1 Where should we haue our thankes?
#
# >+ Line-1   Hor. Not from his mouth,
#
# >+ Line-1 Had it th' abilitie of life to thanke you:
#
# >+ Line-1 He neuer gaue command'ment for their death.
#
# >+ Line-1 But since so iumpe vpon this bloodie question,
#
# >+ Line-1 You from the Polake warres, and you from England
#
# >+ Line-1 Are heere arriued. Giue order that these bodies
#
# >+ Line-1 High on a stage be placed to the view,
#
# >+ Line-1 And let me speake to th' yet vnknowing world,
#
# >+ Line-1 How these things came about. So shall you heare
#
# >+ Line-1 Of carnall, bloudie, and vnnaturall acts,
#
# >+ Line-1 Of accidentall iudgements, casuall slaughters
#
# >+ Line-1 Of death's put on by cunning, and forc'd cause,
#
# >+ Line-1 And in this vpshot, purposes mistooke,
#
# >+ Line-1 Falne on the Inuentors head. All this can I
#
# >+ Line-1 Truly deliuer
#
# >+ Line-1    For. Let vs hast to heare it,
#
# >+ Line-1 And call the Noblest to the Audience.
#
# >+ Line-1 For me, with sorrow, I embrace my Fortune,
#
# >+ Line-1 I haue some Rites of memory in this Kingdome,
#
# >+ Line-1 Which are to claime, my vantage doth
#
# >+ Line-1 Inuite me,
#
# >+ Line-1   Hor. Of that I shall haue alwayes cause to speake,
#
# >+ Line-1 And from his mouth
#
# >+ Line-1 Whose voyce will draw on more:
#
# >+ Line-1 But let this same be presently perform'd,
#
# >+ Line-1 Euen whiles mens mindes are wilde,
#
# >+ Line-1 Lest more mischance
#
# >+ Line-1 On plots, and errors happen
#
# >+ Line-1    For. Let foure Captaines
#
# >+ Line-1 Beare Hamlet like a Soldier to the Stage,
#
# >+ Line-1 For he was likely, had he beene put on
#
# >+ Line-1 To haue prou'd most royally:
#
# >+ Line-1 And for his passage,
#
# >+ Line-1 The Souldiours Musicke, and the rites of Warre
#
# >+ Line-1 Speake lowdly for him.
#
# >+ Line-1 Take vp the body; Such a sight as this
#
# >+ Line-1 Becomes the Field, but heere shewes much amis.
#
# >+ Line-1 Go, bid the Souldiers shoote.
#
# >+ Line-1 Exeunt. Marching: after the which, a Peale of Ordenance are shot
#
# >+ Line-1 off.
#
# >+ Line-1 FINIS. The tragedie of HAMLET, Prince of Denmarke.

# %%
# Close the files
f1.close()
f2.close()
